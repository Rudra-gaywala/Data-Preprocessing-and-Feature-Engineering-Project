# %% [markdown]
# # Data Preprocessing and Feature Engineering Project

# %% [markdown]
# ## Part B: Data Acquisition

# %%
import pandas as pd

df_csv = pd.read_csv('C:\\Users\\RUDRA JATIN GAYWALA\\OneDrive\\Desktop\\ML-projects\\pr-1\\customer_data.csv')

df_json = pd.read_json('C:\\Users\\RUDRA JATIN GAYWALA\\OneDrive\\Desktop\\ML-projects\\pr-1\\customer_data.json')

print(df_csv.head())
print(df_json.head())
# Out:
#    CustomerID   Name  Age Gender  Income  Purchases  Churn
# 0           1   Amit   25      M   40000          5      0
# 1           2   Neha   30      F   60000          8      1
# 2           3   Ravi   22      M   35000          2      0
# 3           4  Priya   35      F   80000         10      1
# 4           5  Karan   28      M   50000          6      0
#    CustomerID   Name  Age Gender  Income  Purchases  Churn
# 0           1   Amit   25      M   40000          5      0
# 1           2   Neha   30      F   60000          8      1
# 2           3   Ravi   22      M   35000          2      0
# 3           4  Priya   35      F   80000         10      1
# 4           5  Karan   28      M   50000          6      0

# %%
with open(r"C:\Users\RUDRA JATIN GAYWALA\OneDrive\Desktop\ML-projects\pr-1\customer_data.sql", "r") as file:
    sql_script = file.read()

print(sql_script)
# Out:
# CREATE TABLE customers (
#     CustomerID INT,
#     Name TEXT,
#     Age INT,
#     Gender TEXT,
#     Income INT,
#     Purchases INT,
#     Churn INT
# );
#
# INSERT INTO customers VALUES (1, 'Amit', 25, 'M', 40000, 5, 0);
# INSERT INTO customers VALUES (2, 'Neha', 30, 'F', 60000, 8, 1);

# %% [markdown]
# ## Part C: Data Understanding & Cleaning

# %%
df = df_csv.copy()

print(df.head())
print(df.info())
print(df.describe())

print(df.isnull().sum())


df = df.drop_duplicates()

df = df.fillna(df.mean(numeric_only=True))
# Out:
#    CustomerID   Name  Age Gender  Income  Purchases  Churn
# 0           1   Amit   25      M   40000          5      0
# 1           2   Neha   30      F   60000          8      1
# 2           3   Ravi   22      M   35000          2      0
# 3           4  Priya   35      F   80000         10      1
# 4           5  Karan   28      M   50000          6      0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  5 non-null      int64
#  1   Name        5 non-null      object
#  2   Age         5 non-null      int64
#  3   Gender      5 non-null      object
#  4   Income      5 non-null      int64
#  5   Purchases   5 non-null      int64
#  6   Churn       5 non-null      int64
# dtypes: int64(5), object(2)
# memory usage: 412.0+ bytes
# None
#        CustomerID        Age       Income  Purchases     Churn
# ...

# %% [markdown]
# ## Part D: Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df['Age'].hist()
plt.title("Age Distribution")
plt.show()

plt.scatter(df['Income'], df['Purchases'])
plt.xlabel("Income")
plt.ylabel("Purchases")
plt.show()


sns.heatmap(df.corr())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 14
#      10 plt.ylabel("Purchases")
#      11 plt.show()
# ---> 14 sns.heatmap(df.corr())
#      15 plt.show()
#
# File c:\Users\RUDRA JATIN GAYWALA\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\RUDRA JATIN GAYWALA\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# ...

# %% [markdown]
# ## Part E: Data Profiling

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, explorative=True)
profile.to_file("report.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ydata_profiling import ProfileReport
#       3 profile = ProfileReport(df, explorative=True)
#       4 profile.to_file("report.html")
#
# File c:\Users\RUDRA JATIN GAYWALA\AppData\Local\Programs\Python\Python313\Lib\site-packages\ydata_profiling\__init__.py:10
#       6 import warnings  # isort:skip # noqa
#       8 import importlib.util  # isort:skip # noqa
# ---> 10 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      11 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      12 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File c:\Users\RUDRA JATIN GAYWALA\AppData\Local\Programs\Python\Python313\Lib\site-packages\ydata_profiling\compare_reports.py:12
# ...
